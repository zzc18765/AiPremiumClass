# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

# 定义神经网络模型
class SimpleMLP(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes):
        super(SimpleMLP, self).__init__()
        # 输入层 -> 隐藏层
        self.fc1 = nn.Linear(input_size, hidden_size)
        # 隐藏层 -> 输出层
        self.fc2 = nn.Linear(hidden_size, num_classes)
        # 激活函数
        self.relu = nn.ReLU()

    def forward(self, x):
        # 输入层 -> 隐藏层
        x = self.fc1(x)
        x = self.relu(x)
        # 隐藏层 -> 输出层
        x = self.fc2(x)
        return x

# 定义超参数
input_size = 28 * 28  # 输入特征维度（MNIST 图像大小为 28x28）
hidden_size = 128      # 隐藏层维度
num_classes = 10       # 输出类别数（MNIST 有 10 个类别）
learning_rate = 0.001  # 学习率
num_epochs = 5         # 训练轮数
batch_size = 64        # 批量大小

# 加载 MNIST 数据集
transform = transforms.Compose([
    transforms.ToTensor(),  # 将图像转换为张量
    transforms.Normalize((0.1307,), (0.3081,))  # 标准化
])

train_dataset = datasets.FashionMNIST(root='./data', train=True, download=False, transform=transform)
test_dataset = datasets.FashionMNIST(root='./data', train=False, download=False, transform=transform)

train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

# 实例化模型
model = SimpleMLP(input_size, hidden_size, num_classes)

# 定义损失函数和优化器
criterion = nn.CrossEntropyLoss()  # 交叉熵损失
optimizer = optim.SGD(model.parameters(), lr=learning_rate) # stochastic gradient descent 随机梯度下降

# 训练模型
total_steps = len(train_loader)
for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(train_loader):
        # 将图像展平为向量
        images = images.reshape(-1, 28 * 28)

        # 前向传播
        outputs = model(images)
        # 计算损失  交叉熵损失
        loss = criterion(outputs, labels)

        # 反向传播和优化
        optimizer.zero_grad()  # 清空梯度
        loss.backward()  # 计算梯度
        optimizer.step()  #  

        # 打印训练进度
        if (i + 1) % 100 == 0:
            print(f"Epoch [{epoch+1}/{num_epochs}], Step [{i+1}/{total_steps}], Loss: {loss.item():.4f}")

# 测试模型
with torch.no_grad():
    correct = 0
    total = 0
    for images, labels in test_loader:
        # 将图像展平为向量
        images = images.reshape(-1, 28 * 28)
        # 前向传播
        outputs = model(images)
        # 获取预测结果
        _, predicted = torch.max(outputs.data, 1)
        # 统计正确预测的数量
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    print(f"测试集准确率: {100 * correct / total:.2f}%")
# Out:
# Epoch [1/5], Step [100/938], Loss: 1.9265
# Epoch [1/5], Step [200/938], Loss: 1.6797
# Epoch [1/5], Step [300/938], Loss: 1.4143
# Epoch [1/5], Step [400/938], Loss: 1.2134
# Epoch [1/5], Step [500/938], Loss: 1.3120
# Epoch [1/5], Step [600/938], Loss: 1.2410
# Epoch [1/5], Step [700/938], Loss: 1.1962
# Epoch [1/5], Step [800/938], Loss: 1.0123
# Epoch [1/5], Step [900/938], Loss: 0.8514
# Epoch [2/5], Step [100/938], Loss: 0.7745
# Epoch [2/5], Step [200/938], Loss: 0.8030
# Epoch [2/5], Step [300/938], Loss: 0.7915
# Epoch [2/5], Step [400/938], Loss: 0.7798
# Epoch [2/5], Step [500/938], Loss: 0.7700
# Epoch [2/5], Step [600/938], Loss: 0.8900
# Epoch [2/5], Step [700/938], Loss: 0.5897
# Epoch [2/5], Step [800/938], Loss: 0.7680
# Epoch [2/5], Step [900/938], Loss: 0.7266
# Epoch [3/5], Step [100/938], Loss: 0.6425
# Epoch [3/5], Step [200/938], Loss: 0.7214
# Epoch [3/5], Step [300/938], Loss: 0.7570
# Epoch [3/5], Step [400/938], Loss: 0.7231
# Epoch [3/5], Step [500/938], Loss: 0.6639
# Epoch [3/5], Step [600/938], Loss: 0.6956
# Epoch [3/5], Step [700/938], Loss: 0.6411
# Epoch [3/5], Step [800/938], Loss: 0.6866
# Epoch [3/5], Step [900/938], Loss: 0.7214
# Epoch [4/5], Step [100/938], Loss: 0.6954
# Epoch [4/5], Step [200/938], Loss: 0.5727
# Epoch [4/5], Step [300/938], Loss: 0.5784
# Epoch [4/5], Step [400/938], Loss: 0.6499
# Epoch [4/5], Step [500/938], Loss: 0.5872
# Epoch [4/5], Step [600/938], Loss: 0.6106
# Epoch [4/5], Step [700/938], Loss: 0.5145
# Epoch [4/5], Step [800/938], Loss: 0.6517
# Epoch [4/5], Step [900/938], Loss: 0.5640
# Epoch [5/5], Step [100/938], Loss: 0.5607
# Epoch [5/5], Step [200/938], Loss: 0.6638
# Epoch [5/5], Step [300/938], Loss: 0.5143
# Epoch [5/5], Step [400/938], Loss: 0.6389
# Epoch [5/5], Step [500/938], Loss: 0.6482
# Epoch [5/5], Step [600/938], Loss: 0.7713
# Epoch [5/5], Step [700/938], Loss: 0.5580
# Epoch [5/5], Step [800/938], Loss: 0.7246
# Epoch [5/5], Step [900/938], Loss: 0.7335
# 测试集准确率: 79.55%
