# %%
from openai import OpenAI

base_url = 'https://open.bigmodel.cn/api/paas/v4'
api_key = '0ea786d9905743a4ac9a4cf7b9e74719.TDE1JQlvq9xVHdxf'
client = OpenAI(
    base_url=base_url,
    api_key=api_key
)
data = {
    'model': 'glm-4-plus',
    'messages': [
        {'role': 'system', 'content': '你是一个图书管理员'},
        {'role': 'assistant', 'content': '图书借阅和归还，根据喜好为读者推荐图书'},
        {'role': 'user', 'content': '我想借一本关于人工智能的书'},
    ],
    'stream': False
}
response = client.chat.completions.create(**data)
print(response.choices[0].message.content)
# Out:
# 当然可以！关于人工智能的书籍有很多种，涵盖了从基础知识到高级应用的各个方面。以下是一些不同类型的书籍推荐，您可以根据自己的兴趣和需求选择：
#
# ### 入门级：
# 1. **《人工智能：一种现代的方法》（Artificial Intelligence: A Modern Approach）**
#    - 作者：Stuart Russell 和 Peter Norvig
#    - 这本书是人工智能领域的经典教材，适合初学者和有一定基础的读者。
#
# 2. **《Python机器学习》（Python Machine Learning）**
#    - 作者：Sebastian Raschka
#    - 适合想要通过Python学习机器学习的读者。
#
# ### 中级：
# 1. **《深度学习》（Deep Learning）**
#    - 作者：Ian Goodfellow, Yoshua Bengio, Aaron Courville
#    - 这本书是深度学习领域的权威著作，适合有一定数学和机器学习基础的读者。
#
# 2. **《强化学习》（Reinforcement Learning: An Introduction）**
#    - 作者：Richard S. Sutton 和 Andrew G. Barto
#    - 专注于强化学习的基本概念和算法。
#
# ### 高级：
# 1. **《模式识别与机器学习》（Pattern Recognition and Machine Learning）**
#    - 作者：Christopher M. Bishop
#    - 适合有一定数学背景的读者，深入探讨了模式识别和机器学习的理论。
#
# 2. **《统计学习方法》**
#    - 作者：李航
#    - 这本书系统地介绍了统计学习的基本概念和方法，适合想要深入研究算法的读者。
#
# ### 应用类：
# 1. **《人工智能：商业应用与实战案例》**
#    - 作者：多位专家合著
#    - 介绍了人工智能在商业领域的实际应用和案例。
#
# 2. **《AI超越：人工智能的下一个十年》**
#    - 作者：李开复
#    - 探讨了人工智能的未来发展趋势和商业应用。
#
# ### 科普类：
# 1. **《智能时代》**
#    - 作者：吴军
#    - 以通俗易懂的方式介绍了人工智能的基本概念和发展历程。
#
# 2. **《人工智能简史》**
#    - 作者：尼克
#    - 从历史角度介绍了人工智能的发展。
#
# 如果您需要更具体的推荐或有其他需求，请告诉我您的阅读背景和兴趣点，我可以为您进一步筛选和推荐。您可以直接来图书馆借阅，或者通过我们的在线系统进行预订。希望这些建议对您有帮助！
