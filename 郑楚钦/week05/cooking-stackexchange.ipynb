# %%
# 使用cooking.stackexchange.txt和fasttext训练文本分类模型
# Fake News数据集

import fasttext

model = fasttext.train_supervised('/kaggle/input/men-are-brothers-word-embedding/cooking.stackexchange.txt')

print(model.labels)
# Out:
# ['__label__baking', '__label__food-safety', '__label__substitutions', '__label__equipment', '__label__bread', '__label__chicken', '__label__storage-method', '__label__eggs', '__label__meat', '__label__cake', '__label__sauce', '__label__flavor', '__label__freezing', '__label__storage-lifetime', '__label__vegetables', '__label__cheese', '__label__oven', '__label__chocolate', '__label__coffee', '__label__oil', '__label__frying', '__label__dough', '__label__temperature', '__label__food-science', '__label__sugar', '__label__fruit', '__label__cookies', '__label__beef', '__label__pasta', '__label__food-preservation', '__label__fish', '__label__rice', '__label__soup', '__label__spices', '__label__salt', '__label__cleaning', '__label__milk', '__label__potatoes', '__label__butter', '__label__flour', '__label__pizza', '__label__cooking-time', '__label__tea', '__label__grilling', '__label__pork', '__label__microwave', '__label__slow-cooking', '__label__steak', '__label__refrigerator', '__label__
# ...

# %%
print(model.words)
# Out:
# ['</s>', 'to', 'a', 'How', 'the', 'I', 'in', 'for', 'of', 'What', 'is', 'and', 'do', 'can', 'with', 'my', 'Why', 'make', 'it', 'Is', 'Can', 'from', 'or', 'be', 'on', 'when', 'use', 'you', 'does', 'are', 'that', 'should', 'cooking', 'chicken', 'there', 'without', 'long', 'cook', 'an', 'bread', '-', 'between', 'Does', 'way', 'substitute', 'food', 'meat', 'at', 'how', 'out', 'safe', 'as', 'after', 'oil', 'have', 'get', 'making', 'difference', 'cream', 'sauce', 'baking', 'Are', 'recipe', 'this', 'milk', 'not', 'cake', 'water', 'chocolate', 'if', 'oven', 'rice', 'what', 'good', 'used', 'using', 'best', 'temperature', 'keep', 'dough', 'store', 'before', 'butter', 'sugar', "What's", 'much', 'cheese', 'taste', 'cooked', 'pan', 'Do', 'frozen', 'fresh', 'beef', 'salt', 'need', 'Should', 'flour', 'coffee', 'too', 'eggs', 'any', 'add', 'into', 'vs', 'like', 'time', 'more', 'white', 'When', 'prevent', 'Cooking', 'egg', 'hot', 'instead', 'so', 'than', 'it?', 'homemade', 'different', 'dry', 'other'
# ...

# %%
model.predict('chicken dinner')
# Out:
# (('__label__food-safety',), array([0.66032356]))
