# %%
from sklearn.datasets import load_iris
import numpy as np
from sklearn.model_selection import train_test_split

X,y = load_iris(return_X_y=True)

# 分别取X,y 后100个数据作为测试集
X = X[:100]
y = y[:100]
# print(X.shape,y.shape)
# 1.准备数据
# 将数据集拆分为训练集和测试集，测试集占30%，随机种子为123以保证可重复性
X_train, X_test, y_train, y_test= train_test_split(X, y, test_size=0.4, random_state=2020,)
# print(X_train.shape,X_test.shape,y_train.shape,y_test.shape)

# 初始化模型参数集合 theta 为权重参数
theta = np.random.randn(30,4)
# print(theta.shape)
# print(X.shape[-1])

# bias 初始化
bias = 0
# 设置学习率
lr = 1e-4

# 设置迭代次数
epochs = 5000

# 2.模型计算
def forward(X,theta,bias):
  # 前向传播 线性回归
  z = np.dot(theta,X.T) + bias
  # sigmoid 函数
  y_hat = 1 / (1 + np.exp(-z))
  return y_hat

  
# 3.计算损失
def loss_function(y,y_hat):
  # 交叉熵损失函数
  e = 1e-3
  loss = -y * np.log(y_hat + e) - (1 - y) * np.log(1 - y_hat + e)
  return loss

# 4.计算梯度下降
def clac_gradient(X,y,y_hat):
  m = X.shape[-1] #样本数量
  delta_w = np.dot((y_hat - y),X) / m
  delta_b = np.mean(y_hat - y) 
  return delta_w,delta_b
  
# 5.更新参数
theta_histroy =[]
for i in range(epochs):
  # 前向传播
  y_hat = forward(X_train,theta,bias)
  
  # 计算损失
  loss = loss_function(y_train,y_hat)
  # 计算梯度
  dw,db = clac_gradient(X_train,y_train,y_hat)
  # 更新参数
  last_theta = theta
  
  theta -= lr * dw
  bias -= lr * db
  
  if i % 100 == 0:
        # 计算准确率
        acc = np.mean(np.round(y_hat) == y_train)   # [False,True,...,False] -> [0,1,...,0]
        print(f"epoch: {i}, loss: {np.mean(loss)}, acc: {acc}")
    
# 保存模型参数
np.savez('model_params.npz',theta=theta,bias=bias) # 保存为 .npz 文件 保存多个数据，npy保存的是单个数组
print("模型参数已保存到 model_params.npz")
# Out:
# epoch: 0, loss: 2.206357781837812, acc: 0.55
# epoch: 100, loss: 1.3616092130641875, acc: 0.5783333333333334
# epoch: 200, loss: 0.8527829347324825, acc: 0.6777777777777778
# epoch: 300, loss: 0.6565360338627144, acc: 0.7622222222222222
# epoch: 400, loss: 0.558704953003074, acc: 0.7611111111111111
# epoch: 500, loss: 0.48978822732541943, acc: 0.7827777777777778
# epoch: 600, loss: 0.4429347256756675, acc: 0.8127777777777778
# epoch: 700, loss: 0.40537066483903905, acc: 0.845
# epoch: 800, loss: 0.3730062519908545, acc: 0.8722222222222222
# epoch: 900, loss: 0.34459851845565764, acc: 0.8955555555555555
