# %% [markdown]
# #### 处理数据

# %%
import csv
import jieba

def load_data(file_pat):
    book_comments = {}
    with open(file_pat, 'r') as f:
        reader = csv.DictReader(f, delimiter='\t')
        for item in reader:
            book = item['book']
            comment = item['body']
            comments_words = jieba.lcut(comment)

            if book == '': continue

            book_comments[book] = book_comments.get(book, [])
            book_comments[book].extend(comments_words)

    return book_comments

# %%
def load_stop_words(file_path):
    stop_words = []  
    with open(file_path, 'r', encoding='utf-8') as f:
        for line in f:
            stop_words.append(line.strip())  
    return stop_words

# %% [markdown]
# #### TF-IDF算法

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity


def tfidf_recommend(book_comments, stop_words):

    books = list(book_comments.keys())
    comments = [' '.join(book_comments[book]) for book in books]

    vectorizer = TfidfVectorizer(stop_words=stop_words)
    tfidf_matrix = vectorizer.fit_transform(comments)

    cosine_similarities = cosine_similarity(tfidf_matrix)

    results = {}
    for idx, book in enumerate(books):
        similar_indices = cosine_similarities[idx].argsort()[:-6:-1]    # 返回前5个最相似的书籍
        similar_books = [(books[i]) for i in similar_indices if i != idx]   
        results[book] = similar_books

    return results

# %% [markdown]
# #### BM25算法

# %%
from rank_bm25 import BM25Okapi as BM25


def BM25_recommend(book_comments, stop_words):

    books = list(book_comments.keys())
    comments = [book_comments[book] for book in books]

    bm25 = BM25(corpus=comments)

    results = {}
    for idx, book in enumerate(books):
        scores = bm25.get_scores(comments[idx])
        similar_indices = sorted(range(len(scores)), key=lambda i: scores[i], reverse=True)[:5]
        similar_books = [(books[i]) for i in similar_indices if i != idx]
        results[book] = similar_books

    return results

# %% [markdown]
# #### 推荐比较

# %%
if __name__ == '__main__':
        
        book_comments = load_data('data/comments_fixed.txt')
        stop_words = load_stop_words('data/stopwords.txt')
    
        tfidf_results = tfidf_recommend(book_comments, stop_words)
        BM25_results = BM25_recommend(book_comments, stop_words)
    
        for book in tfidf_results:
            print('book:', book)
            print('tfidf:', tfidf_results[book])
            print('BM25:', BM25_results[book])
            print('====================')
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\sgp\AppData\Local\Temp\jieba.cache
# Loading model cost 0.901 seconds.
# Prefix dict has been built successfully.
# c:\Users\sgp\miniconda3\envs\py312\Lib\site-packages\sklearn\feature_extraction\text.py:402: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['lex', '①①', '①②', '①③', '①④', '①⑤', '①⑥', '①⑦', '①⑧', '①⑨', '①ａ', '①ｂ', '①ｃ', '①ｄ', '①ｅ', '①ｆ', '①ｇ', '①ｈ', '①ｉ', '①ｏ', '②①', '②②', '②③', '②④', '②⑤', '②⑥', '②⑦', '②⑧', '②⑩', '②ａ', '②ｂ', '②ｄ', '②ｅ', '②ｆ', '②ｇ', '②ｈ', '②ｉ', '②ｊ', '③①', '③⑩', '③ａ', '③ｂ', '③ｃ', '③ｄ', '③ｅ', '③ｆ', '③ｇ', '③ｈ', '④ａ', '④ｂ', '④ｃ', '④ｄ', '④ｅ', '⑤ａ', '⑤ｂ', '⑤ｄ', '⑤ｅ', '⑤ｆ', '１２', 'ｌｉ', 'ｚｘｆｉｔｌ'] not in stop_words.
#   warnings.warn(
# book: 天才在左 疯子在右
# tfidf: ['三体', '人类简史', '拆掉思维里的墙', '少有人走的路']
# BM25: ['三体', '人类简史', '三体Ⅲ', '白夜行']
# ====================
# book: 1Q84 BOOK 1
# tfidf: ['悲伤逆流成河', '1Q84 BOOK 2', '1Q84 BOOK 3', '白夜行']
# BM25: ['白夜行', '1995-2005夏至未至', '茶花女', '局外人']
# ====================
# book: 悲伤逆流成河
# tfidf: ['1Q84 BOOK 1', '左手倒影，右手年华。', '会有天使替我爱你', '幻城']
# BM25: ['梦里花落知多少', '小时代1.0折纸时代', '1Q84 BOOK 1', '幻城']
# ====================
# book: 恶意
# tfidf: ['放学后', '解忧杂货店', '嫌疑人X的献身', '白夜行']
# BM25: ['嫌疑人X的献身', '白夜行', '解忧杂货店', '幻夜']
# ====================
# book: Harry Potter and the Deathly Hallows
# tfidf: ['哈利·波特与魔法石', '哈利·波特与火焰杯', '哈利·波特与密室', '哈利·波特与凤凰社']
# BM25: ['哈利·波特与魔法石', '哈利·波特与火焰杯', '哈利·波特与阿兹卡班的囚徒', '哈利·波特与凤凰社']
# ====================
# book: 长安乱
# tfidf: ['像少年啦飞驰', '零下一度', '三重门', '1988：我想和这个世界谈谈']
# BM25: ['一座城池', '1988：我想和这个世界谈谈', '他的国', '三重门']
# ====================
# book: 苏菲的世界
# tfidf: ['不能承受的生命之轻', '遇见未知的自己', '人类简史', '如何阅读一本书']
# BM25: ['挪威的森林', '遇见未知的自己', '人类简史', '三体']
# ====================
# book: 许三观卖血记
# tfidf: ['活着', '兄弟（上）', '兄弟（下）', '平凡的世界（全三部）']
# BM25: ['活着', '兄弟（下）', '兄弟（上）', '骆驼祥子']
# ====================
# book: 1995-2005夏至未至
# tfidf: ['1Q84 BOOK 1', '白夜行', '茶花女', '局外人']
# BM25: ['1Q84 BOOK 1', '茶花女', '白夜行', '局外人']
# ====================
# book: 盗墓笔记
# tfidf: ['鬼吹灯之精绝古城', '鬼吹灯之云南虫谷', '盗墓笔记3', '盗墓笔记4']
# BM25: ['盗墓笔记3', '盗墓笔记4', '鬼吹灯之精绝古城', '盗墓笔记2']
# ====================
# book: 霍乱时期的爱情
# tfidf: ['百年孤独', '时间旅行者的妻子', '呼啸山庄', '山楂树之恋']
# BM25: ['百年孤独', '白夜行', '嫌疑人X的献身', '致我们终将逝去的青春']
# ====================
# book: 三生三世 十里桃花
# tfidf: ['华胥引（全二册）', '梦里花落知多少', '幻城', '人生若只如初见']
# BM25: ['华胥引（全二册）', '梦里花落知多少', '致我们终将逝去的青春', '小时代1.0折纸时代']
# ====================
# book: 基督山伯爵
# tfidf: ['呼啸山庄', '肖申克的救赎', '哈利·波特与魔法石', '何以笙箫默']
# BM25: ['傲慢与偏见', '呼啸山庄', '白夜行', '三体']
# ====================
# book: 小时代1.0折纸时代
# tfidf: ['左手倒影，右手年华。', '幻城', '关于莉莉周的一切', '西决']
# BM25: ['梦里花落知多少', '致我们终将逝去的青春', '白夜行', '西决']
# ====================
# book: 洛丽塔
# tfidf: ['情人', '在路上', '时间旅行者的妻子', '香水']
# BM25: ['情人', '白夜行', '香水', '嫌疑人X的献身']
# ====================
# book: 1Q84 BOOK 2
# tfidf: ['1Q84 BOOK 3', '世界尽头与冷酷仙境', '海边的卡夫卡', '且听风吟']
# BM25: ['1Q84 BOOK 3', '1Q84 BOOK 1', '白夜行', '世界尽头与冷酷仙境']
# ====================
# book: 第一次的亲密接触
# tfidf: ['会有天使替我爱你', '草样年华', '幻城', '左手倒影，右手年华。']
# BM25: ['梦里花落知多少', '挪威的森林', '悟空传', '幻城']
# ====================
# book: 神雕侠侣
# tfidf: ['射雕英雄传（全四册）', '笑傲江湖（全四册）', '天龙八部', '倚天屠龙记(共四册)']
# BM25: ['射雕英雄传（全四册）', '笑傲江湖（全四册）', '倚天屠龙记(共四册)', '致我们终将逝去的青春']
# ====================
# book: 一座城池
# tfidf: ['像少年啦飞驰', '长安乱', '零下一度', '他的国']
# BM25: ['1988：我想和这个世界谈谈', '他的国', '长安乱', '小时代1.0折纸时代']
# ====================
# book: 茶花女
# tfidf: ['白夜行', '1Q84 BOOK 1', '局外人', '当我谈跑步时我谈些什么']
# BM25: ['1Q84 BOOK 1', '白夜行', '局外人', '1995-2005夏至未至']
# ====================
# book: 当我谈跑步时我谈些什么
# tfidf: ['且听风吟', '世界尽头与冷酷仙境', '1Q84 BOOK 3', '海边的卡夫卡']
# BM25: ['1Q84 BOOK 3', '茶花女', '1Q84 BOOK 2', '挪威的森林']
# ====================
# book: 明朝那些事儿（贰）
# tfidf: ['明朝那些事儿（壹）', '明朝那些事儿（1-9）', '万历十五年', '明朝那些事儿（叁）']
# BM25: ['明朝那些事儿（叁）', '明朝那些事儿（壹）', '明朝那些事儿（1-9）', '明朝那些事儿（肆）']
# ====================
# book: 人类简史
# tfidf: ['明朝那些事儿（壹）', '明朝那些事儿（1-9）', '万历十五年', '三体']
# BM25: ['三体', '万历十五年', '天才在左 疯子在右', '三体Ⅲ']
# ====================
# book: 一個人住第5年
# tfidf: ['挪威的森林', '一个人的好天气', '我的路', '陪安东尼度过漫长岁月']
# BM25: ['挪威的森林', '一个人的好天气', '撒哈拉的故事', '送你一颗子弹']
# ====================
# book: 明朝那些事儿（肆）
# tfidf: ['明朝那些事儿（伍）', '明朝那些事儿（1-9）', '万历十五年', '明朝那些事儿（叁）']
# BM25: ['明朝那些事儿（伍）', '明朝那些事儿（1-9）', '明朝那些事儿（陆）', '明朝那些事儿（叁）']
# ====================
# book: 寻路中国
# tfidf: ['平凡的世界（全三部）', '万历十五年', '皮囊', '历史深处的忧虑']
# BM25: ['看见', '民主的细节', '历史深处的忧虑', '人类简史']
# ====================
# book: 我们台湾这些年
# tfidf: ['这些人，那些事', '明朝那些事儿（壹）', '民主的细节', '明朝那些事儿（1-9）']
# BM25: ['民主的细节', '亲爱的安德烈', '寻路中国', '万历十五年']
# ====================
# book: 1Q84 BOOK 3
# tfidf: ['1Q84 BOOK 2', '世界尽头与冷酷仙境', '海边的卡夫卡', '且听风吟']
# BM25: ['1Q84 BOOK 2', '1Q84 BOOK 1', '白夜行', '世界尽头与冷酷仙境']
# ====================
# book: 摆渡人
# tfidf: ['何以笙箫默', '华胥引（全二册）', '偷影子的人', '时间旅行者的妻子']
# BM25: ['致我们终将逝去的青春', '白夜行', '嫌疑人X的献身', '解忧杂货店']
# ====================
# book: 明朝那些事儿（伍）
# tfidf: ['万历十五年', '明朝那些事儿（1-9）', '明朝那些事儿（肆）', '明朝那些事儿（陆）']
# BM25: ['明朝那些事儿（肆）', '明朝那些事儿（陆）', '明朝那些事儿（1-9）', '万历十五年']
# ====================
# book: 骆驼祥子
# tfidf: ['平凡的世界（全三部）', '活着', '穆斯林的葬礼', '无声告白']
# BM25: ['活着', '白夜行', '挪威的森林', '刀锋']
# ====================
# book: 盗墓笔记3
# tfidf: ['盗墓笔记4', '盗墓笔记', '盗墓笔记2', '鬼吹灯之精绝古城']
# BM25: ['盗墓笔记4', '盗墓笔记2', '盗墓笔记', '鬼吹灯之精绝古城']
# ====================
# book: 麦琪的礼物
# tfidf: ['时间旅行者的妻子', '最初的爱情 最后的仪式', '偷影子的人', '华胥引（全二册）']
# BM25: ['羊脂球', '时间旅行者的妻子', '当我们谈论爱情时我们在谈论什么', '最初的爱情 最后的仪式']
# ====================
# book: 格林童话全集
# tfidf: ['安徒生童话故事集', '机器猫哆啦A梦23', '哈利·波特与魔法石', '窗边的小豆豆']
# BM25: ['安徒生童话故事集', '小王子', '傲慢与偏见', '哈利·波特与魔法石']
# ====================
# book: 水仙已乘鲤鱼去
# tfidf: ['大地之灯', '会有天使替我爱你', '被窝是青春的坟墓', '左手倒影，右手年华。']
# BM25: ['梦里花落知多少', '莲花', '致我们终将逝去的青春', '挪威的森林']
# ====================
# book: 历史深处的忧虑
# tfidf: ['民主的细节', '在路上', '万历十五年', '一九八四·动物农场']
# BM25: ['民主的细节', '人类简史', '寻路中国', '万历十五年']
# ====================
# book: 金锁记
# tfidf: ['小团圆', '倾城之恋', '半生缘', '红玫瑰与白玫瑰']
# BM25: ['倾城之恋', '半生缘', '小团圆', '白夜行']
# ====================
# book: 草样年华
# tfidf: ['此间的少年', '左手倒影，右手年华。', '会有天使替我爱你', '那些回不去的年少时光']
# BM25: ['梦里花落知多少', '挪威的森林', '致我们终将逝去的青春', '一座城池']
# ====================
# book: 刀锋
# tfidf: ['月亮和六便士', '一个人的朝圣', '在路上', '平凡的世界（全三部）']
# BM25: ['霍乱时期的爱情', '一个人的朝圣', '局外人', '白夜行']
# ====================
# book: 飞鸟集
# tfidf: ['Harry Potter and the Deathly Hallows', '麦田里的守望者', '芒果街上的小屋', '左手倒影，右手年华。']
# BM25: ['麦田里的守望者', '梦里花落知多少', '挪威的森林', '撒哈拉的故事']
# ====================
# book: 七夜雪
# tfidf: ['何以笙箫默', '长安乱', '大地之灯', '华胥引（全二册）']
# BM25: ['华胥引（全二册）', '致我们终将逝去的青春', '梦里花落知多少', '白夜行']
# ====================
# book: 最初的爱情 最后的仪式
# tfidf: ['华胥引（全二册）', '乖，摸摸头', '皮囊', '偷影子的人']
# BM25: ['白夜行', '挪威的森林', '嫌疑人X的献身', '1Q84 BOOK 2']
# ====================
# book: 拆掉思维里的墙
# tfidf: ['把时间当作朋友', '少有人走的路', '遇见未知的自己', '如何阅读一本书']
# BM25: ['把时间当作朋友', '少有人走的路', '遇见未知的自己', '人类简史']
# ====================
# book: 明朝那些事儿（陆）
# tfidf: ['明朝那些事儿（1-9）', '万历十五年', '明朝那些事儿（柒）：大结局', '明朝那些事儿（壹）']
# BM25: ['明朝那些事儿（柒）：大结局', '明朝那些事儿（伍）', '明朝那些事儿（1-9）', '明朝那些事儿（肆）']
# ====================
# book: 追风筝的人
# tfidf: ['灿烂千阳', '偷影子的人', '一个人的朝圣', '肖申克的救赎']
# BM25: ['灿烂千阳', '一个人的朝圣', '白夜行', '无声告白']
# ====================
# book: 小王子
# tfidf: ['这些都是你给我的爱', '牧羊少年奇幻之旅', '阿狸·梦之城堡', '陪安东尼度过漫长岁月']
# BM25: ['牧羊少年奇幻之旅', '梦里花落知多少', '挪威的森林', '撒哈拉的故事']
# ====================
# book: 围城
# tfidf: ['三重门', '我们仨', '零下一度', '他的国']
# BM25: ['我们仨', '倾城之恋', '挪威的森林', '傲慢与偏见']
# ====================
# book: 解忧杂货店
# tfidf: ['恶意', '嫌疑人X的献身', '放学后', '白夜行']
# BM25: ['白夜行', '嫌疑人X的献身', '恶意', '幻夜']
# ====================
# book: 活着
# tfidf: ['许三观卖血记', '兄弟（上）', '兄弟（下）', '平凡的世界（全三部）']
# BM25: ['许三观卖血记', '平凡的世界（全三部）', '兄弟（上）', '白夜行']
# ====================
# book: 白夜行
# tfidf: ['幻夜', '三体', '解忧杂货店', '三体Ⅱ']
# BM25: ['1Q84 BOOK 1', '局外人', '茶花女', '我们仨']
# ====================
# book: 挪威的森林
# tfidf: ['且听风吟', '海边的卡夫卡', '世界尽头与冷酷仙境', '1Q84 BOOK 3']
# BM25: ['且听风吟', '世界尽头与冷酷仙境', '1Q84 BOOK 2', '1Q84 BOOK 3']
# ====================
# book: 嫌疑人X的献身
# tfidf: ['解忧杂货店', '恶意', '放学后', '白夜行']
# BM25: ['白夜行', '恶意', '解忧杂货店', '幻夜']
# ====================
# book: 三体
# tfidf: ['三体Ⅱ', '三体Ⅲ', '球状闪电', '白夜行']
# BM25: ['三体Ⅲ', '白夜行', '三体Ⅱ', '天才在左 疯子在右']
# ====================
# book: 不能承受的生命之轻
# tfidf: ['苏菲的世界', '霍乱时期的爱情', '情人', '挪威的森林']
# BM25: ['霍乱时期的爱情', '挪威的森林', '刀锋', '白夜行']
# ====================
# book: 红楼梦
# tfidf: ['三国演义（全二册）', '百年孤独', '步步惊心', '人生若只如初见']
# BM25: ['百年孤独', '傲慢与偏见', '挪威的森林', '围城']
# ====================
# book: 梦里花落知多少
# tfidf: ['撒哈拉的故事', '哭泣的骆驼', '幻城', '三生三世 十里桃花']
# BM25: ['撒哈拉的故事', '哭泣的骆驼', '小时代1.0折纸时代', '致我们终将逝去的青春']
# ====================
# book: 达·芬奇密码
# tfidf: ['天使与魔鬼', '穆斯林的葬礼', '哈利·波特与魔法石', '失恋33天']
# BM25: ['嫌疑人X的献身', '白夜行', '三体', '1Q84 BOOK 2']
# ====================
# book: 看见
# tfidf: ['送你一颗子弹', '皮囊', '寻路中国', '乖，摸摸头']
# BM25: ['寻路中国', '送你一颗子弹', '皮囊', '民主的细节']
# ====================
# book: 百年孤独
# tfidf: ['孤独六讲', '霍乱时期的爱情', '挪威的森林', '荆棘鸟']
# BM25: ['霍乱时期的爱情', '白夜行', '三体Ⅲ', '挪威的森林']
# ====================
# book: 1988：我想和这个世界谈谈
# tfidf: ['像少年啦飞驰', '零下一度', '他的国', '长安乱']
# BM25: ['他的国', '一座城池', '皮囊', '小时代1.0折纸时代']
# ====================
# book: 何以笙箫默
# tfidf: ['原来你还在这里', '会有天使替我爱你', '微微一笑很倾城', '泡沫之夏']
# BM25: ['致我们终将逝去的青春', '微微一笑很倾城', '原来你还在这里', '华胥引（全二册）']
# ====================
# book: 平凡的世界（全三部）
# tfidf: ['穆斯林的葬礼', '皮囊', '活着', '一个人的朝圣']
# BM25: ['活着', '皮囊', '挪威的森林', '许三观卖血记']
# ====================
# book: 简爱
# tfidf: ['呼啸山庄', '傲慢与偏见', '钢铁是怎样炼成的', '原来你还在这里']
# BM25: ['傲慢与偏见', '呼啸山庄', '挪威的森林', '致我们终将逝去的青春']
# ====================
# book: 哈利·波特与魔法石
# tfidf: ['哈利·波特与密室', '哈利·波特与火焰杯', '哈利·波特与凤凰社', 'Harry Potter and the Deathly Hallows']
# BM25: ['哈利·波特与密室', '哈利·波特与火焰杯', '哈利·波特与阿兹卡班的囚徒', '哈利·波特与凤凰社']
# ====================
# book: 三体Ⅱ
# tfidf: ['三体Ⅲ', '三体', '白夜行', '球状闪电']
# BM25: ['三体Ⅲ', '白夜行', '三体', '人类简史']
# ====================
# book: 飘
# tfidf: ['傲慢与偏见', '呼啸山庄', '简爱', '时间旅行者的妻子']
# BM25: ['傲慢与偏见', '挪威的森林', '简爱', '梦里花落知多少']
# ====================
# book: 送你一颗子弹
# tfidf: ['民主的细节', '佛祖在一号线', '皮囊', '人类简史']
# BM25: ['民主的细节', '看见', '历史深处的忧虑', '皮囊']
# ====================
# book: 三体Ⅲ
# tfidf: ['三体Ⅱ', '三体', '球状闪电', '白夜行']
# BM25: ['三体', '白夜行', '三体Ⅱ', '球状闪电']
# ====================
# book: 傲慢与偏见
# tfidf: ['呼啸山庄', '简爱', '飘', '何以笙箫默']
# BM25: ['简爱', '飘', '呼啸山庄', '挪威的森林']
# ====================
# book: 倾城之恋
# tfidf: ['小团圆', '半生缘', '金锁记', '红玫瑰与白玫瑰']
# BM25: ['半生缘', '金锁记', '小团圆', '红玫瑰与白玫瑰']
# ====================
# book: 三重门
# tfidf: ['零下一度', '像少年啦飞驰', '长安乱', '1988：我想和这个世界谈谈']
# BM25: ['零下一度', '一座城池', '1988：我想和这个世界谈谈', '梦里花落知多少']
# ====================
# book: 杜拉拉升职记
# tfidf: ['杜拉拉2华年似水', '拆掉思维里的墙', '致我们终将逝去的青春', '失恋33天']
# BM25: ['杜拉拉2华年似水', '致我们终将逝去的青春', '拆掉思维里的墙', '看见']
# ====================
# book: 明朝那些事儿（壹）
# tfidf: ['明朝那些事儿（1-9）', '万历十五年', '明朝那些事儿（贰）', '明朝那些事儿（柒）：大结局']
# BM25: ['明朝那些事儿（1-9）', '明朝那些事儿（贰）', '万历十五年', '明朝那些事儿（肆）']
# ====================
# book: 哈利·波特与阿兹卡班的囚徒
# tfidf: ['哈利·波特与凤凰社', '哈利·波特与火焰杯', '哈利·波特与密室', '哈利·波特与魔法石']
# BM25: ['哈利·波特与凤凰社', '哈利·波特与密室', 'Harry Potter and the Deathly Hallows', '哈利·波特与火焰杯']
# ====================
# book: 目送
# tfidf: ['孩子你慢慢来', '亲爱的安德烈', '皮囊', '无声告白']
# BM25: ['孩子你慢慢来', '亲爱的安德烈', '皮囊', '看见']
# ====================
# book: 情人
# tfidf: ['霍乱时期的爱情', '时间旅行者的妻子', '一只特立独行的猪', '不能承受的生命之轻']
# BM25: ['霍乱时期的爱情', '挪威的森林', '不能承受的生命之轻', '洛丽塔']
# ====================
# book: 哈利·波特与密室
# tfidf: ['哈利·波特与魔法石', '哈利·波特与火焰杯', '哈利·波特与凤凰社', '哈利·波特与阿兹卡班的囚徒']
# BM25: ['哈利·波特与阿兹卡班的囚徒', '哈利·波特与魔法石', '哈利·波特与火焰杯', '哈利·波特与凤凰社']
# ====================
# book: 万历十五年
# tfidf: ['明朝那些事儿（1-9）', '明朝那些事儿（壹）', '明朝那些事儿（伍）', '明朝那些事儿（陆）']
# BM25: ['明朝那些事儿（1-9）', '明朝那些事儿（伍）', '明朝那些事儿（陆）', '明朝那些事儿（壹）']
# ====================
# book: 我们仨
# tfidf: ['围城', '无声告白', '皮囊', '平凡的世界（全三部）']
# BM25: ['白夜行', '围城', '局外人', '1Q84 BOOK 1']
# ====================
# book: 幻城
# tfidf: ['左手倒影，右手年华。', '小时代1.0折纸时代', '会有天使替我爱你', '梦里花落知多少']
# BM25: ['梦里花落知多少', '小时代1.0折纸时代', '左手倒影，右手年华。', '三重门']
# ====================
# book: 致我们终将逝去的青春
# tfidf: ['那些回不去的年少时光', '那些年，我们一起追的女孩', '关于莉莉周的一切', '原来你还在这里']
# BM25: ['原来你还在这里', '何以笙箫默', '那些回不去的年少时光', '挪威的森林']
# ====================
# book: 狼图腾
# tfidf: ['人类简史', '明朝那些事儿（1-9）', '穆斯林的葬礼', '明朝那些事儿（壹）']
# BM25: ['三体', '人类简史', '白夜行', '天才在左 疯子在右']
# ====================
# book: 微微一笑很倾城
# tfidf: ['何以笙箫默', '会有天使替我爱你', '泡沫之夏', '原来你还在这里']
# BM25: ['何以笙箫默', '致我们终将逝去的青春', '华胥引（全二册）', '嫌疑人X的献身']
# ====================
# book: 莲花
# tfidf: ['蔷薇岛屿', '清醒纪', '二三事', '八月未央']
# BM25: ['八月未央', '1988：我想和这个世界谈谈', '二三事', '撒哈拉的故事']
# ====================
# book: 哈利·波特与火焰杯
# tfidf: ['哈利·波特与魔法石', '哈利·波特与密室', '哈利·波特与凤凰社', '哈利·波特与阿兹卡班的囚徒']
# BM25: ['哈利·波特与阿兹卡班的囚徒', '哈利·波特与凤凰社', '哈利·波特与魔法石', '哈利·波特与密室']
# ====================
# book: 边城
# tfidf: ['皮囊', '一个人的好天气', '平凡的世界（全三部）', '偷影子的人']
# BM25: ['伊豆的舞女', '致我们终将逝去的青春', '撒哈拉的故事', '挪威的森林']
# ====================
# book: 月亮和六便士
# tfidf: ['刀锋', '霍乱时期的爱情', '一个人的朝圣', '呼啸山庄']
# BM25: ['刀锋', '霍乱时期的爱情', '嫌疑人X的献身', '三体Ⅲ']
# ====================
# book: 向左走·向右走
# tfidf: ['月亮忘記了', '地下铁', '我的路', '这些都是你给我的爱']
# BM25: ['地下铁', '月亮忘記了', '倾城之恋', '挪威的森林']
# ====================
# book: 穆斯林的葬礼
# tfidf: ['平凡的世界（全三部）', '达·芬奇密码', '何以笙箫默', '大地之灯']
# BM25: ['平凡的世界（全三部）', '白夜行', '致我们终将逝去的青春', '嫌疑人X的献身']
# ====================
# book: 从你的全世界路过
# tfidf: ['乖，摸摸头', '小时代1.0折纸时代', '关于莉莉周的一切', '摆渡人']
# BM25: ['摆渡人', '解忧杂货店', '皮囊', '天才在左 疯子在右']
# ====================
# book: 天龙八部
# tfidf: ['射雕英雄传（全四册）', '笑傲江湖（全四册）', '鹿鼎记（全五册）', '此间的少年']
# BM25: ['笑傲江湖（全四册）', '神雕侠侣', '射雕英雄传（全四册）', '此间的少年']
# ====================
# book: 放学后
# tfidf: ['恶意', '解忧杂货店', '嫌疑人X的献身', '白夜行']
# BM25: ['恶意', '嫌疑人X的献身', '白夜行', '幻夜']
# ====================
# book: 哈利·波特与混血王子
# tfidf: ['哈利·波特与密室', '哈利·波特与火焰杯', 'Harry Potter and the Deathly Hallows', '哈利·波特与凤凰社']
# BM25: ['哈利·波特与凤凰社', 'Harry Potter and the Deathly Hallows', '哈利·波特与密室', '哈利·波特与阿兹卡班的囚徒']
# ====================
# book: 一个人的好天气
# tfidf: ['菊与刀', '伊豆的舞女', '一個人住第5年', '偷影子的人']
# BM25: ['挪威的森林', '白夜行', '解忧杂货店', '霍乱时期的爱情']
# ====================
# book: 哈利·波特与凤凰社
# tfidf: ['哈利·波特与阿兹卡班的囚徒', '哈利·波特与火焰杯', '哈利·波特与密室', '哈利·波特与魔法石']
# BM25: ['哈利·波特与阿兹卡班的囚徒', '哈利·波特与火焰杯', 'Harry Potter and the Deathly Hallows', '哈利·波特与密室']
# ====================
# book: 喜宝
# tfidf: ['何以笙箫默', '原来你还在这里', '霍乱时期的爱情', '曾有一个人，爱我如生命']
# BM25: ['致我们终将逝去的青春', '傲慢与偏见', '倾城之恋', '霍乱时期的爱情']
# ====================
# book: 岛上书店
# tfidf: ['平凡的世界（全三部）', '1988：我想和这个世界谈谈', '小时代1.0折纸时代', '何以笙箫默']
# BM25: ['三体', '皮囊', '伊豆的舞女', '不能承受的生命之轻']
# ====================
# book: 海边的卡夫卡
# tfidf: ['世界尽头与冷酷仙境', '且听风吟', '1Q84 BOOK 3', '挪威的森林']
# BM25: ['挪威的森林', '世界尽头与冷酷仙境', '1Q84 BOOK 3', '1Q84 BOOK 2']
# ====================
# book: 文化苦旅
# tfidf: ['左手倒影，右手年华。', '会有天使替我爱你', '大地之灯', '幻城']
# BM25: ['撒哈拉的故事', '梦里花落知多少', '民主的细节', '挪威的森林']
# ====================
# book: 窗边的小豆豆
# tfidf: ['孩子你慢慢来', '格林童话全集', '安徒生童话故事集', '哈利·波特与魔法石']
# BM25: ['孩子你慢慢来', '撒哈拉的故事', '小王子', '挪威的森林']
# ====================
# book: 三国演义（全二册）
# tfidf: ['明朝那些事儿（1-9）', '红楼梦', '明朝那些事儿（壹）', '万历十五年']
# BM25: ['明朝那些事儿（1-9）', '红楼梦', '明朝那些事儿（肆）', '明朝那些事儿（伍）']
# ====================
# book: 黄金时代
# tfidf: ['沉默的大多数', '一只特立独行的猪', '爱你就像爱生命', '情人']
# BM25: ['挪威的森林', '爱你就像爱生命', '沉默的大多数', '霍乱时期的爱情']
# ====================
# book: 悟空传
# tfidf: ['第一次的亲密接触', '会有天使替我爱你', '左手倒影，右手年华。', '何以笙箫默']
# BM25: ['挪威的森林', '致我们终将逝去的青春', '白夜行', '梦里花落知多少']
# ====================
# book: 兄弟（上）
# tfidf: ['兄弟（下）', '许三观卖血记', '活着', '平凡的世界（全三部）']
# BM25: ['兄弟（下）', '许三观卖血记', '活着', '平凡的世界（全三部）']
# ====================
# book: 呼啸山庄
# tfidf: ['简爱', '基督山伯爵', '傲慢与偏见', '霍乱时期的爱情']
# BM25: ['傲慢与偏见', '简爱', '白夜行', '挪威的森林']
# ====================
# book: 笑傲江湖（全四册）
# tfidf: ['射雕英雄传（全四册）', '天龙八部', '鹿鼎记（全五册）', '神雕侠侣']
# BM25: ['神雕侠侣', '射雕英雄传（全四册）', '此间的少年', '倚天屠龙记(共四册)']
# ====================
# book: 少有人走的路
# tfidf: ['把时间当作朋友', '拆掉思维里的墙', '遇见未知的自己', '如何阅读一本书']
# BM25: ['把时间当作朋友', '拆掉思维里的墙', '遇见未知的自己', '一个人的朝圣']
# ====================
# book: 民主的细节
# tfidf: ['送你一颗子弹', '历史深处的忧虑', '动物农场', '常识']
# BM25: ['历史深处的忧虑', '送你一颗子弹', '人类简史', '常识']
# ====================
# book: 亲爱的安德烈
# tfidf: ['孩子你慢慢来', '目送', '无声告白', '皮囊']
# BM25: ['孩子你慢慢来', '目送', '无声告白', '看见']
# ====================
# book: 灿烂千阳
# tfidf: ['追风筝的人', '偷影子的人', '平凡的世界（全三部）', '穆斯林的葬礼']
# BM25: ['追风筝的人', '白夜行', '霍乱时期的爱情', '活着']
# ====================
# book: 老人与海
# tfidf: ['一个人的好天气', '一个人的朝圣', '百年孤独', '孤独六讲']
# BM25: ['霍乱时期的爱情', '挪威的森林', '活着', '一个人的朝圣']
# ====================
# book: 遇见未知的自己
# tfidf: ['少有人走的路', '拆掉思维里的墙', '秘密', '如何阅读一本书']
# BM25: ['少有人走的路', '拆掉思维里的墙', '牧羊少年奇幻之旅', '一个人的朝圣']
# ====================
# book: 一九八四·动物农场
# tfidf: ['1984', '动物农场', '人类简史', '历史深处的忧虑']
# BM25: ['1984', '动物农场', '三体Ⅲ', '白夜行']
# ====================
# book: 牧羊少年奇幻之旅
# tfidf: ['小王子', '一个人的朝圣', '遇见未知的自己', '三体Ⅲ']
# BM25: ['一个人的朝圣', '刀锋', '解忧杂货店', '无声告白']
# ====================
# book: 福尔摩斯探案全集（上中下）
# tfidf: ['东方快车谋杀案', '哈利·波特与魔法石', '钢铁是怎样炼成的', '鲁滨逊漂流记']
# BM25: ['嫌疑人X的献身', '傲慢与偏见', '梦里花落知多少', '挪威的森林']
# ====================
# book: 素年锦时
# tfidf: ['清醒纪', '蔷薇岛屿', '八月未央', '二三事']
# BM25: ['莲花', '八月未央', '清醒纪', '告别薇安']
# ====================
# book: 情书
# tfidf: ['关于莉莉周的一切', '失恋33天', '肖申克的救赎', '香水']
# BM25: ['挪威的森林', '致我们终将逝去的青春', '嫌疑人X的献身', '山楂树之恋']
# ====================
# book: 他的国
# tfidf: ['像少年啦飞驰', '1988：我想和这个世界谈谈', '长安乱', '零下一度']
# BM25: ['1988：我想和这个世界谈谈', '一座城池', '小时代1.0折纸时代', '长安乱']
# ====================
# book: 彼岸花
# tfidf: ['八月未央', '清醒纪', '二三事', '告别薇安']
# BM25: ['莲花', '二三事', '八月未央', '告别薇安']
# ====================
# book: 西决
# tfidf: ['东霓', '小时代1.0折纸时代', '大地之灯', '左手倒影，右手年华。']
# BM25: ['东霓', '白夜行', '致我们终将逝去的青春', '梦里花落知多少']
# ====================
# book: 东方快车谋杀案
# tfidf: ['恶意', '嫌疑人X的献身', '福尔摩斯探案全集（上中下）', '放学后']
# BM25: ['嫌疑人X的献身', '恶意', '白夜行', '解忧杂货店']
# ====================
# book: 这些都是你给我的爱
# tfidf: ['陪安东尼度过漫长岁月', '橙', '小王子', '阿狸·梦之城堡']
# BM25: ['橙', '陪安东尼度过漫长岁月', '小王子', '牧羊少年奇幻之旅']
# ====================
# book: 这些人，那些事
# tfidf: ['我们台湾这些年', '皮囊', '乖，摸摸头', '偷影子的人']
# BM25: ['皮囊', '看见', '撒哈拉的故事', '致我们终将逝去的青春']
# ====================
# book: 八月未央
# tfidf: ['清醒纪', '告别薇安', '二三事', '彼岸花']
# BM25: ['告别薇安', '莲花', '二三事', '清醒纪']
# ====================
# book: 清醒纪
# tfidf: ['蔷薇岛屿', '八月未央', '素年锦时', '二三事']
# BM25: ['莲花', '八月未央', '蔷薇岛屿', '二三事']
# ====================
# book: 一个陌生女人的来信
# tfidf: ['时间旅行者的妻子', '霍乱时期的爱情', '无声告白', '情人']
# BM25: ['嫌疑人X的献身', '霍乱时期的爱情', '情人', '撒哈拉的故事']
# ====================
# book: 蔡康永的说话之道
# tfidf: ['拆掉思维里的墙', '如何阅读一本书', '遇见未知的自己', '把时间当作朋友']
# BM25: ['拆掉思维里的墙', '把时间当作朋友', '遇见未知的自己', '杜拉拉升职记']
# ====================
# book: 偷影子的人
# tfidf: ['时间旅行者的妻子', '那些回不去的年少时光', '何以笙箫默', '皮囊']
# BM25: ['一个人的朝圣', '解忧杂货店', '摆渡人', '皮囊']
# ====================
# book: 陪安东尼度过漫长岁月
# tfidf: ['橙', '这些都是你给我的爱', '被窝是青春的坟墓', '左手倒影，右手年华。']
# BM25: ['橙', '梦里花落知多少', '挪威的森林', '送你一颗子弹']
# ====================
# book: 沉默的大多数
# tfidf: ['一只特立独行的猪', '黄金时代', '爱你就像爱生命', '零下一度']
# BM25: ['一只特立独行的猪', '黄金时代', '送你一颗子弹', '民主的细节']
# ====================
# book: 白鹿原
# tfidf: ['平凡的世界（全三部）', '寻路中国', '百年孤独', '明朝那些事儿（1-9）']
# BM25: ['白夜行', '三体Ⅲ', '三体', '平凡的世界（全三部）']
# ====================
# book: 芒果街上的小屋
# tfidf: ['这些都是你给我的爱', '陪安东尼度过漫长岁月', '我的路', '偷影子的人']
# BM25: ['撒哈拉的故事', '梦里花落知多少', '牧羊少年奇幻之旅', '麦田里的守望者']
# ====================
# book: 羊脂球
# tfidf: ['钢铁是怎样炼成的', '呼啸山庄', '简爱', '左手倒影，右手年华。']
# BM25: ['茶花女', '傲慢与偏见', '骆驼祥子', '挪威的森林']
# ====================
# book: 鲁滨逊漂流记
# tfidf: ['钢铁是怎样炼成的', '哈利·波特与魔法石', '简爱', '机器猫哆啦A梦23']
# BM25: ['傲慢与偏见', '挪威的森林', '撒哈拉的故事', '梦里花落知多少']
# ====================
# book: 灌篮高手31
# tfidf: ['海贼王', '机器猫哆啦A梦23', '那些年，我们一起追的女孩', '那些回不去的年少时光']
# BM25: ['海贼王', '梦里花落知多少', '挪威的森林', '那些回不去的年少时光']
# ====================
# book: 撒哈拉的故事
# tfidf: ['哭泣的骆驼', '梦里花落知多少', '乖，摸摸头', '被窝是青春的坟墓']
# BM25: ['哭泣的骆驼', '梦里花落知多少', '孩子你慢慢来', '倾城之恋']
# ====================
# book: 巴黎圣母院
# tfidf: ['悲惨世界（上中下）', '呼啸山庄', '简爱', '钢铁是怎样炼成的']
# BM25: ['悲惨世界（上中下）', '傲慢与偏见', '香水', '茶花女']
# ====================
# book: 肖申克的救赎
# tfidf: ['失恋33天', '香水', '关于莉莉周的一切', '达·芬奇密码']
# BM25: ['嫌疑人X的献身', '白夜行', '一个人的朝圣', '解忧杂货店']
# ====================
# book: 麦田里的守望者
# tfidf: ['在路上', 'Harry Potter and the Deathly Hallows', '挪威的森林', '那些回不去的年少时光']
# BM25: ['在路上', '挪威的森林', '人间失格', '刀锋']
# ====================
# book: 无声告白
# tfidf: ['皮囊', '孩子你慢慢来', '亲爱的安德烈', '偷影子的人']
# BM25: ['白夜行', '一个人的朝圣', '皮囊', '霍乱时期的爱情']
# ====================
# book: 山楂树之恋
# tfidf: ['霍乱时期的爱情', '时间旅行者的妻子', '何以笙箫默', '穆斯林的葬礼']
# BM25: ['致我们终将逝去的青春', '嫌疑人X的献身', '霍乱时期的爱情', '梦里花落知多少']
# ====================
# book: 华胥引（全二册）
# tfidf: ['三生三世 十里桃花', '何以笙箫默', '乖，摸摸头', '原来你还在这里']
# BM25: ['三生三世 十里桃花', '致我们终将逝去的青春', '步步惊心', '白夜行']
# ====================
# book: 地下铁
# tfidf: ['向左走·向右走', '月亮忘記了', '我的路', '这些都是你给我的爱']
# BM25: ['月亮忘記了', '向左走·向右走', '我的路', '挪威的森林']
# ====================
# book: 且听风吟
# tfidf: ['世界尽头与冷酷仙境', '海边的卡夫卡', '1Q84 BOOK 3', '挪威的森林']
# BM25: ['挪威的森林', '世界尽头与冷酷仙境', '1Q84 BOOK 2', '1Q84 BOOK 3']
# ====================
# book: 钢铁是怎样炼成的
# tfidf: ['鲁滨逊漂流记', '会有天使替我爱你', '哈利·波特与魔法石', '简爱']
# BM25: ['挪威的森林', '傲慢与偏见', '梦里花落知多少', '飘']
# ====================
# book: 红玫瑰与白玫瑰
# tfidf: ['倾城之恋', '小团圆', '金锁记', '半生缘']
# BM25: ['倾城之恋', '围城', '霍乱时期的爱情', '挪威的森林']
# ====================
# book: 人生若只如初见
# tfidf: ['三生三世 十里桃花', '幻城', '大地之灯', '左手倒影，右手年华。']
# BM25: ['梦里花落知多少', '步步惊心', '红楼梦', '华胥引（全二册）']
# ====================
# book: 人间失格
# tfidf: ['一个人的好天气', '无声告白', '皮囊', '一个人的朝圣']
# BM25: ['白夜行', '挪威的森林', '嫌疑人X的献身', '局外人']
# ====================
# book: 鬼吹灯之精绝古城
# tfidf: ['盗墓笔记', '鬼吹灯之云南虫谷', '盗墓笔记3', '盗墓笔记4']
# BM25: ['盗墓笔记', '鬼吹灯之云南虫谷', '盗墓笔记3', '盗墓笔记4']
# ====================
# book: 安徒生童话故事集
# tfidf: ['格林童话全集', '机器猫哆啦A梦23', '哈利·波特与魔法石', '窗边的小豆豆']
# BM25: ['格林童话全集', '小王子', '傲慢与偏见', '哈利·波特与魔法石']
# ====================
# book: 呐喊
# tfidf: ['阿Q正传', '沉默的大多数', '穆斯林的葬礼', '左手倒影，右手年华。']
# BM25: ['阿Q正传', '骆驼祥子', '许三观卖血记', '沉默的大多数']
# ====================
# book: 小团圆
# tfidf: ['倾城之恋', '半生缘', '金锁记', '红玫瑰与白玫瑰']
# BM25: ['倾城之恋', '半生缘', '霍乱时期的爱情', '挪威的森林']
# ====================
# book: 泡沫之夏
# tfidf: ['会有天使替我爱你', '何以笙箫默', '步步惊心', '原来你还在这里']
# BM25: ['会有天使替我爱你', '何以笙箫默', '致我们终将逝去的青春', '微微一笑很倾城']
# ====================
# book: 会有天使替我爱你
# tfidf: ['泡沫之夏', '何以笙箫默', '左手倒影，右手年华。', '幻城']
# BM25: ['泡沫之夏', '梦里花落知多少', '何以笙箫默', '微微一笑很倾城']
# ====================
# book: 1984
# tfidf: ['一九八四·动物农场', '动物农场', '人类简史', '万历十五年']
# BM25: ['一九八四·动物农场', '动物农场', '白夜行', '三体Ⅲ']
# ====================
# book: 年华是无效信
# tfidf: ['不朽', '被窝是青春的坟墓', '左手倒影，右手年华。', '那些回不去的年少时光']
# BM25: ['梦里花落知多少', '那些回不去的年少时光', '挪威的森林', '不朽']
# ====================
# book: 幻夜
# tfidf: ['白夜行', '嫌疑人X的献身', '解忧杂货店', '恶意']
# BM25: ['白夜行', '嫌疑人X的献身', '恶意', '解忧杂货店']
# ====================
# book: 在路上
# tfidf: ['麦田里的守望者', '历史深处的忧虑', '一个人的朝圣', '一个人的好天气']
# BM25: ['麦田里的守望者', '挪威的森林', '刀锋', '一个人的朝圣']
# ====================
# book: 射雕英雄传（全四册）
# tfidf: ['神雕侠侣', '此间的少年', '笑傲江湖（全四册）', '天龙八部']
# BM25: ['神雕侠侣', '笑傲江湖（全四册）', '此间的少年', '倚天屠龙记(共四册)']
# ====================
# book: 明朝那些事儿（1-9）
# tfidf: ['明朝那些事儿（壹）', '万历十五年', '明朝那些事儿（柒）：大结局', '明朝那些事儿（陆）']
# BM25: ['明朝那些事儿（壹）', '明朝那些事儿（肆）', '明朝那些事儿（柒）：大结局', '明朝那些事儿（陆）']
# ====================
# book: 月亮忘記了
# tfidf: ['向左走·向右走', '地下铁', '阿狸·梦之城堡', '我的路']
# BM25: ['地下铁', '向左走·向右走', '我的路', '阿狸·梦之城堡']
# ====================
# book: 明朝那些事儿（叁）
# tfidf: ['明朝那些事儿（1-9）', '明朝那些事儿（肆）', '明朝那些事儿（贰）', '万历十五年']
# BM25: ['明朝那些事儿（肆）', '明朝那些事儿（1-9）', '明朝那些事儿（贰）', '明朝那些事儿（陆）']
# ====================
# book: 哭泣的骆驼
# tfidf: ['撒哈拉的故事', '梦里花落知多少', '乖，摸摸头', '被窝是青春的坟墓']
# BM25: ['撒哈拉的故事', '梦里花落知多少', '骆驼祥子', '半生缘']
# ====================
# book: 原来你还在这里
# tfidf: ['何以笙箫默', '致我们终将逝去的青春', '华胥引（全二册）', '那些回不去的年少时光']
# BM25: ['致我们终将逝去的青春', '何以笙箫默', '华胥引（全二册）', '那些回不去的年少时光']
# ====================
# book: 半生缘
# tfidf: ['小团圆', '倾城之恋', '金锁记', '那些回不去的年少时光']
# BM25: ['倾城之恋', '金锁记', '致我们终将逝去的青春', '小团圆']
# ====================
# book: 此间的少年
# tfidf: ['射雕英雄传（全四册）', '草样年华', '天龙八部', '笑傲江湖（全四册）']
# BM25: ['射雕英雄传（全四册）', '致我们终将逝去的青春', '梦里花落知多少', '那些回不去的年少时光']
# ====================
# book: 货币战争
# tfidf: ['人类简史', '历史深处的忧虑', '达·芬奇密码', '明朝那些事儿（1-9）']
# BM25: ['人类简史', '天才在左 疯子在右', '民主的细节', '三体']
# ====================
# book: 佳期如梦
# tfidf: ['会有天使替我爱你', '彼岸花', '遇见未知的自己', '1984']
# BM25: ['梦里花落知多少', '巴黎圣母院', '香水', '傲慢与偏见']
# ====================
# book: 无人生还
# tfidf: ['鲁滨逊漂流记', '恶意', '放学后', '东方快车谋杀案']
# BM25: ['嫌疑人X的献身', '幻夜', '恶意', '白夜行']
# ====================
# book: 了不起的盖茨比
# tfidf: ['时间旅行者的妻子', '霍乱时期的爱情', '挪威的森林', '历史深处的忧虑']
# BM25: ['挪威的森林', '刀锋', '霍乱时期的爱情', '白夜行']
# ====================
# book: 时间旅行者的妻子
# tfidf: ['霍乱时期的爱情', '麦琪的礼物', '何以笙箫默', '三体']
# BM25: ['霍乱时期的爱情', '白夜行', '解忧杂货店', '三体Ⅲ']
# ====================
# book: 告别薇安
# tfidf: ['八月未央', '二三事', '清醒纪', '蔷薇岛屿']
# BM25: ['八月未央', '莲花', '二三事', '挪威的森林']
# ====================
# book: 常识
# tfidf: ['佛祖在一号线', '民主的细节', '送你一颗子弹', '沉默的大多数']
# BM25: ['民主的细节', '送你一颗子弹', '人类简史', '历史深处的忧虑']
# ====================
# book: 爱你就像爱生命
# tfidf: ['一只特立独行的猪', '沉默的大多数', '黄金时代', '霍乱时期的爱情']
# BM25: ['黄金时代', '霍乱时期的爱情', '撒哈拉的故事', '一只特立独行的猪']
# ====================
# book: 步步惊心
# tfidf: ['泡沫之夏', '华胥引（全二册）', '何以笙箫默', '会有天使替我爱你']
# BM25: ['华胥引（全二册）', '致我们终将逝去的青春', '嫌疑人X的献身', '白夜行']
# ====================
# book: 皮囊
# tfidf: ['无声告白', '乖，摸摸头', '大地之灯', '这些人，那些事']
# BM25: ['看见', '无声告白', '寻路中国', '解忧杂货店']
# ====================
# book: 二三事
# tfidf: ['清醒纪', '告别薇安', '八月未央', '蔷薇岛屿']
# BM25: ['莲花', '八月未央', '告别薇安', '蔷薇岛屿']
# ====================
# book: 兄弟（下）
# tfidf: ['兄弟（上）', '许三观卖血记', '活着', '平凡的世界（全三部）']
# BM25: ['兄弟（上）', '许三观卖血记', '活着', '致我们终将逝去的青春']
# ====================
# book: 孤独六讲
# tfidf: ['百年孤独', '且听风吟', '挪威的森林', '老人与海']
# BM25: ['人类简史', '挪威的森林', '天才在左 疯子在右', '送你一颗子弹']
# ====================
# book: 乌合之众
# tfidf: ['人类简史', '拆掉思维里的墙', '少有人走的路', '如何阅读一本书']
# BM25: ['人类简史', '民主的细节', '天才在左 疯子在右', '拆掉思维里的墙']
# ====================
# book: 盗墓笔记2
# tfidf: ['盗墓笔记3', '盗墓笔记', '盗墓笔记4', '鬼吹灯之精绝古城']
# BM25: ['盗墓笔记3', '盗墓笔记', '盗墓笔记4', '鬼吹灯之精绝古城']
# ====================
# book: 失恋33天
# tfidf: ['肖申克的救赎', '香水', '关于莉莉周的一切', '达·芬奇密码']
# BM25: ['致我们终将逝去的青春', '嫌疑人X的献身', '小时代1.0折纸时代', '傲慢与偏见']
# ====================
# book: 动物农场
# tfidf: ['一九八四·动物农场', '1984', '人类简史', '民主的细节']
# BM25: ['1984', '一九八四·动物农场', '人类简史', '百年孤独']
# ====================
# book: 左耳
# tfidf: ['左手倒影，右手年华。', '被窝是青春的坟墓', '致我们终将逝去的青春', '会有天使替我爱你']
# BM25: ['梦里花落知多少', '致我们终将逝去的青春', '挪威的森林', '何以笙箫默']
# ====================
# book: 鹿鼎记（全五册）
# tfidf: ['射雕英雄传（全四册）', '天龙八部', '笑傲江湖（全四册）', '神雕侠侣']
# BM25: ['神雕侠侣', '笑傲江湖（全四册）', '射雕英雄传（全四册）', '基督山伯爵']
# ====================
# book: 荆棘鸟
# tfidf: ['霍乱时期的爱情', '时间旅行者的妻子', '呼啸山庄', '简爱']
# BM25: ['霍乱时期的爱情', '百年孤独', '白夜行', '挪威的森林']
# ====================
# book: 左手倒影，右手年华。
# tfidf: ['幻城', '小时代1.0折纸时代', '被窝是青春的坟墓', '会有天使替我爱你']
# BM25: ['梦里花落知多少', '幻城', '小时代1.0折纸时代', '三重门']
# ====================
# book: 零下一度
# tfidf: ['像少年啦飞驰', '三重门', '长安乱', '1988：我想和这个世界谈谈']
# BM25: ['三重门', '像少年啦飞驰', '长安乱', '一座城池']
# ====================
# book: 像少年啦飞驰
# tfidf: ['零下一度', '三重门', '长安乱', '1988：我想和这个世界谈谈']
# BM25: ['一座城池', '1988：我想和这个世界谈谈', '三重门', '长安乱']
# ====================
# book: 被窝是青春的坟墓
# tfidf: ['大地之灯', '左手倒影，右手年华。', '那些回不去的年少时光', '清醒纪']
# BM25: ['梦里花落知多少', '莲花', '西决', '致我们终将逝去的青春']
# ====================
# book: 关于莉莉周的一切
# tfidf: ['致我们终将逝去的青春', '小时代1.0折纸时代', '情书', '左手倒影，右手年华。']
# BM25: ['挪威的森林', '梦里花落知多少', '致我们终将逝去的青春', '小时代1.0折纸时代']
# ====================
# book: 机器猫哆啦A梦23
# tfidf: ['格林童话全集', '海贼王', '灌篮高手31', '哈利·波特与魔法石']
# BM25: ['傲慢与偏见', '灌篮高手31', '梦里花落知多少', '哈利·波特与魔法石']
# ====================
# book: 阿Q正传
# tfidf: ['呐喊', '沉默的大多数', '穆斯林的葬礼', '他的国']
# BM25: ['呐喊', '骆驼祥子', '沉默的大多数', '麦田里的守望者']
# ====================
# book: 乖，摸摸头
# tfidf: ['皮囊', '华胥引（全二册）', '大地之灯', '穆斯林的葬礼']
# BM25: ['皮囊', '撒哈拉的故事', '解忧杂货店', '看见']
# ====================
# book: 大地之灯
# tfidf: ['清醒纪', '告别薇安', '八月未央', '二三事']
# BM25: ['莲花', '西决', '梦里花落知多少', '致我们终将逝去的青春']
# ====================
# book: 如何阅读一本书
# tfidf: ['把时间当作朋友', '拆掉思维里的墙', '遇见未知的自己', '少有人走的路']
# BM25: ['把时间当作朋友', '拆掉思维里的墙', '遇见未知的自己', '人类简史']
# ====================
# book: 当我们谈论爱情时我们在谈论什么
# tfidf: ['霍乱时期的爱情', '皮囊', '时间旅行者的妻子', '最初的爱情 最后的仪式']
# BM25: ['最初的爱情 最后的仪式', '白夜行', '挪威的森林', '霍乱时期的爱情']
# ====================
# book: 尘埃落定
# tfidf: ['穆斯林的葬礼', '平凡的世界（全三部）', '大地之灯', '达·芬奇密码']
# BM25: ['百年孤独', '挪威的森林', '平凡的世界（全三部）', '白夜行']
# ====================
# book: 小时代2.0虚铜时代
# tfidf: ['不朽', '哈利·波特与阿兹卡班的囚徒', '边城', '哈利·波特与火焰杯', '莲花']
# BM25: ['天才在左 疯子在右', '1Q84 BOOK 1', '悲伤逆流成河', '恶意', 'Harry Potter and the Deathly Hallows']
# ====================
# book: 东霓
# tfidf: ['西决', '大地之灯', '原来你还在这里', '何以笙箫默']
# BM25: ['西决', '白夜行', '致我们终将逝去的青春', '嫌疑人X的献身']
# ====================
# book: 海贼王
# tfidf: ['灌篮高手31', '机器猫哆啦A梦23', '我的路', '那些年，我们一起追的女孩']
# BM25: ['灌篮高手31', '傲慢与偏见', '白夜行', '三体Ⅲ']
# ====================
# book: 那些回不去的年少时光
# tfidf: ['致我们终将逝去的青春', '匆匆那年（上下）', '被窝是青春的坟墓', '那些年，我们一起追的女孩']
# BM25: ['致我们终将逝去的青春', '梦里花落知多少', '挪威的森林', '皮囊']
# ====================
# book: 孩子你慢慢来
# tfidf: ['亲爱的安德烈', '目送', '无声告白', '窗边的小豆豆']
# BM25: ['亲爱的安德烈', '目送', '无声告白', '撒哈拉的故事']
# ====================
# book: 橙
# tfidf: ['陪安东尼度过漫长岁月', '这些都是你给我的爱', '一个人的好天气', '我的路']
# BM25: ['陪安东尼度过漫长岁月', '梦里花落知多少', '挪威的森林', '致我们终将逝去的青春']
# ====================
# book: 悲惨世界（上中下）
# tfidf: ['巴黎圣母院', '哈利·波特与魔法石', '钢铁是怎样炼成的', '基督山伯爵']
# BM25: ['巴黎圣母院', '白夜行', '活着', '茶花女']
# ====================
# book: 盗墓笔记4
# tfidf: ['盗墓笔记3', '盗墓笔记', '盗墓笔记2', '鬼吹灯之精绝古城']
# BM25: ['盗墓笔记3', '盗墓笔记', '盗墓笔记2', '鬼吹灯之精绝古城']
# ====================
# book: 巴别塔之犬
# tfidf: ['时间旅行者的妻子', '无声告白', '一个人的朝圣', '霍乱时期的爱情']
# BM25: ['无声告白', '一个人的朝圣', '白夜行', '嫌疑人X的献身']
# ====================
# book: 香水
# tfidf: ['失恋33天', '肖申克的救赎', '达·芬奇密码', '时间旅行者的妻子']
# BM25: ['嫌疑人X的献身', '白夜行', '霍乱时期的爱情', '三体Ⅲ']
# ====================
# book: 一只特立独行的猪
# tfidf: ['沉默的大多数', '黄金时代', '爱你就像爱生命', '情人']
# BM25: ['沉默的大多数', '黄金时代', '送你一颗子弹', '情人']
# ====================
# book: 局外人
# tfidf: ['白夜行', '茶花女', '1Q84 BOOK 1', '人间失格']
# BM25: ['白夜行', '1Q84 BOOK 1', '茶花女', '我们仨']
# ====================
# book: 一个人的朝圣
# tfidf: ['在路上', '平凡的世界（全三部）', '乖，摸摸头', '无声告白']
# BM25: ['牧羊少年奇幻之旅', '无声告白', '解忧杂货店', '霍乱时期的爱情']
# ====================
# book: 史蒂夫·乔布斯传
# tfidf: ['拆掉思维里的墙', '天才在左 疯子在右', '平凡的世界（全三部）', '月亮和六便士']
# BM25: ['刀锋', '看见', '牧羊少年奇幻之旅', '嫌疑人X的献身']
# ====================
# book: 看不见的城市
# tfidf: ['被窝是青春的坟墓', '向左走·向右走', '地下铁', '如何阅读一本书']
# BM25: ['刀锋', '百年孤独', '三体', '霍乱时期的爱情']
# ====================
# book: 长恨歌
# tfidf: ['小时代1.0折纸时代', '倾城之恋', '小团圆', '大地之灯']
# BM25: ['倾城之恋', '白夜行', '霍乱时期的爱情', '围城']
# ====================
# book: 匆匆那年（上下）
# tfidf: ['那些回不去的年少时光', '致我们终将逝去的青春', '原来你还在这里', '被窝是青春的坟墓']
# BM25: ['致我们终将逝去的青春', '那些回不去的年少时光', '梦里花落知多少', '原来你还在这里']
# ====================
# book: 蔷薇岛屿
# tfidf: ['清醒纪', '二三事', '素年锦时', '八月未央']
# BM25: ['莲花', '清醒纪', '二三事', '八月未央']
# ====================
# book: 我的路
# tfidf: ['阿狸·梦之城堡', '向左走·向右走', '这些都是你给我的爱', '陪安东尼度过漫长岁月']
# BM25: ['地下铁', '梦里花落知多少', '挪威的森林', '阿狸·梦之城堡']
# ====================
# book: 菊与刀
# tfidf: ['伊豆的舞女', '一个人的好天气', '明朝那些事儿（伍）', '人间失格']
# BM25: ['历史深处的忧虑', '人类简史', '寻路中国', '白夜行']
# ====================
# book: 球状闪电
# tfidf: ['三体', '三体Ⅲ', '三体Ⅱ', '白夜行']
# BM25: ['三体', '三体Ⅲ', '白夜行', '三体Ⅱ']
# ====================
# book: 谁动了我的奶酪？
# tfidf: ['拆掉思维里的墙', '钢铁是怎样炼成的', '遇见未知的自己', '会有天使替我爱你']
# BM25: ['牧羊少年奇幻之旅', '挪威的森林', '拆掉思维里的墙', '遇见未知的自己']
# ====================
# book: 曾有一个人，爱我如生命
# tfidf: ['何以笙箫默', '原来你还在这里', '会有天使替我爱你', '华胥引（全二册）']
# BM25: ['致我们终将逝去的青春', '梦里花落知多少', '霍乱时期的爱情', '何以笙箫默']
# ====================
# book: 那些年，我们一起追的女孩
# tfidf: ['致我们终将逝去的青春', '那些回不去的年少时光', '被窝是青春的坟墓', '关于莉莉周的一切']
# BM25: ['致我们终将逝去的青春', '那些回不去的年少时光', '梦里花落知多少', '挪威的森林']
# ====================
# book: 伊豆的舞女
# tfidf: ['菊与刀', '一个人的好天气', '且听风吟', '挪威的森林']
# BM25: ['挪威的森林', '且听风吟', '边城', '白夜行']
# ====================
# book: 世界尽头与冷酷仙境
# tfidf: ['海边的卡夫卡', '且听风吟', '1Q84 BOOK 3', '1Q84 BOOK 2']
# BM25: ['1Q84 BOOK 3', '1Q84 BOOK 2', '挪威的森林', '海边的卡夫卡']
# ====================
# book: 鬼吹灯之云南虫谷
# tfidf: ['鬼吹灯之精绝古城', '盗墓笔记', '盗墓笔记3', '盗墓笔记4']
# BM25: ['鬼吹灯之精绝古城', '盗墓笔记', '盗墓笔记3', '盗墓笔记4']
# ====================
# book: 明朝那些事儿（柒）：大结局
# tfidf: ['明朝那些事儿（1-9）', '明朝那些事儿（壹）', '明朝那些事儿（陆）', '万历十五年']
# BM25: ['明朝那些事儿（陆）', '明朝那些事儿（1-9）', '万历十五年', '明朝那些事儿（肆）']
# ====================
# book: 把时间当作朋友
# tfidf: ['拆掉思维里的墙', '少有人走的路', '如何阅读一本书', '时间旅行者的妻子']
# BM25: ['拆掉思维里的墙', '少有人走的路', '遇见未知的自己', '如何阅读一本书']
# ====================
# book: 秘密
# tfidf: ['遇见未知的自己', '拆掉思维里的墙', '三体Ⅱ', '三体Ⅲ']
# BM25: ['遇见未知的自己', '拆掉思维里的墙', '少有人走的路', '牧羊少年奇幻之旅']
# ====================
# book: 天使与魔鬼
# tfidf: ['达·芬奇密码', '失恋33天', '哈利·波特与魔法石', '穆斯林的葬礼']
# BM25: ['达·芬奇密码', '嫌疑人X的献身', '1Q84 BOOK 2', '三体']
# ====================
# book: 佛祖在一号线
# tfidf: ['常识', '送你一颗子弹', '沉默的大多数', '皮囊']
# BM25: ['送你一颗子弹', '民主的细节', '常识', '看见']
# ====================
# book: 倚天屠龙记(共四册)
# tfidf: ['射雕英雄传（全四册）', '天龙八部', '笑傲江湖（全四册）', '神雕侠侣']
# BM25: ['笑傲江湖（全四册）', '神雕侠侣', '射雕英雄传（全四册）', '半生缘']
# ====================
# book: 阿狸·梦之城堡
# tfidf: ['我的路', '这些都是你给我的爱', '向左走·向右走', '小王子']
# BM25: ['我的路', '小王子', '橙', '孩子你慢慢来']
# ====================
# book: 杜拉拉2华年似水
# tfidf: ['杜拉拉升职记', '拆掉思维里的墙', '哈利·波特与魔法石', '三体Ⅱ']
# BM25: ['杜拉拉升职记', '致我们终将逝去的青春', '白夜行', '拆掉思维里的墙']
# ====================
# book: 不朽
# tfidf: ['年华是无效信', '左手倒影，右手年华。', '被窝是青春的坟墓', '大地之灯']
# BM25: ['年华是无效信', '梦里花落知多少', '那些回不去的年少时光', '挪威的森林']
# ====================
